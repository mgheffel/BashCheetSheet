# %%
import os

# %%
# os.listdir('impute/25k/')

# %%
with open('impute/25k/snakemake_cmd.txt','r')as f:
    for counter, line in enumerate(f, 1):
        output_file = "snakemake_cmd"+str(counter)+".txt"
        print(line,output_file)
        with open("impute/25k/"+output_file, 'w')as outf:
            outf.write(line.strip()+'\n')
# Out:
# snakemake -d /u/project/cluo/heffel/organoid_grant/impute/25k/chunk0 --snakefile /u/project/cluo/heffel/organoid_grant/impute/25k/chunk0/Snakefile -j 4
#  snakemake_cmd1.txt
# snakemake -d /u/project/cluo/heffel/organoid_grant/impute/25k/chunk1 --snakefile /u/project/cluo/heffel/organoid_grant/impute/25k/chunk1/Snakefile -j 4
#  snakemake_cmd2.txt
# snakemake -d /u/project/cluo/heffel/organoid_grant/impute/25k/chunk2 --snakefile /u/project/cluo/heffel/organoid_grant/impute/25k/chunk2/Snakefile -j 4
#  snakemake_cmd3.txt
# snakemake -d /u/project/cluo/heffel/organoid_grant/impute/25k/chunk3 --snakefile /u/project/cluo/heffel/organoid_grant/impute/25k/chunk3/Snakefile -j 4
#  snakemake_cmd4.txt
# snakemake -d /u/project/cluo/heffel/organoid_grant/impute/25k/chunk4 --snakefile /u/project/cluo/heffel/organoid_grant/impute/25k/chunk4/Snakefile -j 4
#  snakemake_cmd5.txt
# ...
